# %%
import numpy as np 
import pandas as pd 
import gc
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %%
import datetime

# %%
import seaborn as sns

# %%
# df = pd.read_csv('D:/Загрузки/phones_test_22_12_11_22_12_18-2.csv')

# %%
# df
# Out:
#          Unnamed: 0     item_id                  start_time  event_date  \
# 0                 0  2213033147  2022-01-05 12:58:03.068759  2022-12-17
# 1                 1  2230380047  2022-04-24 10:18:42.480340  2022-12-14
# 2                 2  2230740988  2022-04-19 23:14:27.763517  2022-12-17
# 3                 3  2231358585  2022-01-04 09:44:52.623021  2022-12-17
# 4                 4  2253554193  2022-03-19 12:26:51.055397  2022-12-15
# ...             ...         ...                         ...         ...
# 1101972     1101972  2762754570  2022-12-12 22:05:43.944261  2022-12-17
# 1101973     1101973  2762755385  2022-12-17 13:16:27.882523  2022-12-17
# 1101974     1101974  2762779890  2022-12-15 10:33:42.434415  2022-12-17
# 1101975     1101975  2762785779  2022-12-12 19:32:26.114502  2022-12-17
# 1101976     1101976  2762786771  2022-12-17 10:38:01.862610  2022-12-17
#
#            price             city                 region  usd_currency  \
# ...

# %%
df_train = pd.read_csv('D:/Загрузки/phones_train_21_12_10_22_12_10.csv')

# %%
df_train[1:50]
# Out:
#     Unnamed: 0     item_id                  start_time  event_date    price  \
# 1            1  1734976392  2021-05-06 15:32:35.328419  2022-06-14  30990.0
# 2            2  1734979316  2021-05-06 17:35:24.029450  2022-06-14  49490.0
# 3            3  1734979713  2021-05-06 17:51:49.031661  2022-06-14  35490.0
# 4            4  1734995547  2021-05-07 14:43:55.153322  2022-06-14  45990.0
# 5            5  1734995681  2021-05-07 14:49:59.275886  2022-06-14  45990.0
# 6            6  1734996104  2021-05-07 15:09:57.462969  2022-06-14  45990.0
# 7            7  1735010950  2021-05-08 12:27:01.318769  2022-06-14  28990.0
# 8            8  1736104127  2021-05-11 16:06:45.968727  2022-03-03   7000.0
# 9            9  1736975189  2021-05-03 19:13:43.845353  2022-08-26   6000.0
# 10          10  1737972504  2021-04-10 09:48:08.576251  2022-07-28   4000.0
# 11          11  1738025117  2021-04-12 12:41:02.002414  2022-09-17    399.0
# ...

# %%
df_train.columns.values.tolist ()
# Out:
# ['Unnamed: 0',
#  'item_id',
#  'start_time',
#  'event_date',
#  'price',
#  'city',
#  'region',
#  'usd_currency',
#  'euro_currency',
#  'description',
#  'close_date',
#  'rating',
#  'active_reviews_count',
#  'rating_reviews_count',
#  'user_items_count',
#  'user_closed_items_count',
#  'close_reason',
#  'color',
#  'vendor',
#  'ram_size',
#  'vstroennaya_pamyat',
#  'memory_size',
#  'model',
#  'sostoyanie',
#  'rasshirennoe_sostoyanie']

# %%
# df_train['active_reviews_count'].head(15)
# df_train['rating_reviews_count'].head(15)
# df_train['rating'].head(15)

# %%
# Время между закрытием объявления и последним изменением по нему
event_close_time = np.array([])
for i in range(100000):
    x = datetime.datetime.strptime(df_train['close_date'][i], '%Y-%m-%d %H:%M:%S.%f') - datetime.datetime.strptime(df_train['event_date'][i], '%Y-%m-%d')
    event_close_time = np.append(event_close_time,x.days)

# %%
event_close_time
# Out:
# array([ 3.,  0.,  0., ...,  0., 17.,  7.])

# %%
groups1 = df_train.vendor.value_counts()
plt.figure(figsize=(20,5))
plt.bar(groups1.index.values[:30].astype('str'),groups1.values[:30])
plt.xticks(rotation = 45)
plt.ylabel('Счётчик',size=14)
plt.xlabel('Фирма',size=14)
plt.title('Top 30 фирм',size=16)
plt.show()

# %%
len(groups2)
# Out:
# 10021

# %%
groups2 = df_train.model.value_counts()
plt.figure(figsize=(20,5))
plt.bar(groups2.index.values[:30].astype('str'),groups2.values[:30])
plt.xticks(rotation = 45)
plt.ylabel('Счётчик',size=14)
plt.xlabel('модель',size=14)
plt.title('Top 50 моделей',size=16)
plt.show()

# %%
groups3 = df_train.close_reason.value_counts()
plt.figure(figsize=(20,5))
plt.bar(groups3.index.values[:30].astype('str'),groups3.values[:30])
plt.xticks(rotation = 45)
plt.ylabel('Счётчик',size=14)
plt.xlabel('Причина',size=14)
plt.title('Top 50 причин',size=16)
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,8.27)})

# %%
plt.xscale('linear')
sns.distplot(df_train[df_train.price < 200000]['price'], hist = False, kde = True,
            kde_kws = {'linewidth': 3})
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(event_close_time[event_close_time<100], hist=True, kde=True, 
             bins=int(100), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

#видно, что подавляющее большинство объявлений закрываются на следующей день после последнего изменения
#Так же есть непонятные случаи, когда дата закрытия объявления на день раньше даты последнего изменения по нему. Возможно, от них придется избавиться(благо таких слувчаев совсем не много)
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
n=0
for i in range(100000):
    if event_close_time[i]<0:
        n = n + 1

n
# Out:
# 1261
